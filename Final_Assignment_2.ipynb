# %% [markdown]
# # Scott's Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Scott Kim**
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because of its limitless potential in every industry!_

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > My IBM Watson Account had a problem so I am uploading the document via GitHub!
# >
#  - Bullet point with text 1
#  - Bullet point with text 2
#
# <hr>
#
# Made by [My Github](https://github.com/kimsajang99)
